# %% [markdown]
# # Introducing an Interactive Visualization App
# # Explore the Soundscape Dataset
#
# ### What's the dataset?
# - Large crowdsourced dataset of Indoor Soundscapes
# - 105 participants rated sound scenes in their homes
# - constant person features
#     - from things regarding habitation to personal wellbeing and health
# - 6594 observations at their homes
# - per observation features
#     - from personal and situational factors to soundscape properties
#
# ### What's the deal?
# - Descriptive Stats have been done before
# - Some basic and advanced statistical modelling has been applied
# - One of the core findings:
#     - For real life field study data, you can not reproduce the numbers from lab studies
#     - not surprising but also a bit sad?
#     - The data might be too noisy
# - also, we have not yet found a meaningful way to work with the timeseries
#
# ## Questions
# ##### 1. What's the noise actually like?
# ##### 2. Is it explorable in an insightful way?
# ##### 3. Can we find meaningful time-patterns in the data?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
from src.preprocess import load_data

# %%
(
    _,
    _,
    df,
    distinct_df,
    _,
    _,
) = load_data()

# %%
distinct_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 distinct_df.info()
#
# NameError: name 'distinct_df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6594 entries, 53 to 20
# Data columns (total 96 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        6594 non-null   int64
#  1   Trigger_counter           6594 non-null   int64
#  2   TriggerType               6594 non-null   object
#  3   Trigger_time              6594 non-null   object
#  4   Form_finish_time          6594 non-null   object
#  5   Week                      6594 non-null   int64
#  6   Instructor                6594 non-null   int64
#  7   RecDevice                 6594 non-null   int64
#  8   VoltageA                  5808 non-null   float64
#  9   VoltageB                  5808 non-null   float64
#  10  Clipping                  5808 non-null   float64
#  11  AirTemperature            5808 non-null   float64
#  12  AirHumidity               5808 non-null   float64
#  13  AirPressure               5808 non-null   float64
#  14  Luminosity                5808 non-null   float64
#  15  Age                       6594 non-null   int64
#  16  Gender                    6594 non-null   object
#  17  Health                    6594 non-null   float64
#  18  Noise_sensitivity_sleep   6594 non-null   float64
#  19  Noise_sensitivity_work    6594 non-null   float64
#  20  Noise_sensitivity_habit   6594 non-null   float64
#  21  Noise_sensitivity         6594 non-null   float64
#  22  Hearing_impairment        6594 non-null   float64
#  23  Trait_mood                6594 non-null   float64
#  24  Trait_wakefulness         6594 non-null   float64
#  25  Trait_rest                6594 non-null   float64
#  26  Wellbeing                 6594 non-null   float64
#  27  Anxiety                   6594 non-null   float64
#  28  Attachment                6594 non-null   float64
#  29  Neighbors_above           6594 non-null   object
#  30  Neighbors_below           6594 non-null   object
#  31  Neighbors_next_door       6594 non-null   object
#  32  Children_joung            6594 non-null   object
#  33  Children_old              6594 non-null   object
#  34  Children                  6594 non-null   object
#  35  People_in_household       6594 non-null   int64
#  36  Valence                   6594 non-null   float64
#  37  Arousal                   6594 non-null   float64
#  38  Wakefulness               6594 non-null   float64
#  39  Control                   6594 non-null   float64
#  40  Cognitive_load            6594 non-null   float64
#  41  Physical_load             6594 non-null   float64
#  42  Activity                  6594 non-null   object
#  43  Location8                 6594 non-null   object
#  44  Location5                 6594 non-null   object
#  45  RT_DEN                    6594 non-null   object
#  46  FGfrequency               6594 non-null   int64
#  47  FGperiodicity             6594 non-null   int64
#  48  FGloudnessVerb            6594 non-null   int64
#  49  FGloudnessNum             6594 non-null   int64
#  50  FGloudness                6594 non-null   int64
#  51  FGsalience                6594 non-null   int64
#  52  Salient_sound_preference  6594 non-null   int64
#  53  Sal_sound_cat             6594 non-null   object
#  54  Sal_sound_cat3            6594 non-null   object
#  55  FGeventfulness            6594 non-null   float64
#  56  FGpleasantness            6594 non-null   float64
#  57  FGpleasant                6594 non-null   int64
#  58  FGchaotic                 6594 non-null   int64
#  59  FGvibrant                 6594 non-null   int64
#  60  FGuneventful              6594 non-null   float64
#  61  FGcalm                    6594 non-null   float64
#  62  FGannoying                6594 non-null   float64
#  63  FGeventful                6594 non-null   int64
#  64  FGmonotonous              6594 non-null   float64
#  65  FGowner                   6594 non-null   object
#  66  Salient_source_ownership  6594 non-null   object
#  67  FGsource                  6594 non-null   object
#  68  Loudness_categorical      6594 non-null   int64
#  69  Loudness_numerical        6594 non-null   int64
#  70  Perceived_loudness        6594 non-null   int64
#  71  Predicted_Loudness        6594 non-null   float64
#  72  LAF5                      6594 non-null   float64
#  73  LAeq                      6594 non-null   float64
#  74  SC_Nature                 6594 non-null   int64
#  75  SC_Human                  6594 non-null   int64
#  76  SC_Household              6594 non-null   int64
#  77  SC_Installation           6594 non-null   int64
#  78  SC_Signals                6594 non-null   int64
#  79  SC_Traffic                6594 non-null   int64
#  80  SC_Speech                 6594 non-null   int64
#  81  SC_Music                  6594 non-null   int64
#  82  Soundscape_eventfulness   6594 non-null   float64
#  83  Soundscape_pleasantness   6594 non-null   float64
#  84  BGpleasant                6594 non-null   int64
#  85  BGchaotic                 6594 non-null   int64
#  86  BGvibrant                 6594 non-null   int64
#  87  BGuneventful              6594 non-null   int64
#  88  BGcalm                    6594 non-null   int64
#  89  BGannoying                6594 non-null   int64
#  90  BGeventful                6594 non-null   int64
#  91  BGmonotonous              6594 non-null   int64
#  92  Voices                    6594 non-null   int64
#  93  n_obs_id                  6594 non-null   int64
#  94  Common_location           6594 non-null   object
#  95  Time                      6594 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(36), int64(39), object(20)
# memory usage: 4.9+ MB

# %%
sns.jointplot(x="Perceived_loudness", y="Soundscape_pleasantness", data=df, alpha=0.3, height=10)
plt.suptitle("Is quiter more pleasant?")
plt.tight_layout()

# %% [markdown]
# ### What my app can't do:
# - It's not a statistical model
# - It's not a predictive
# - You will most definitely miss something

# %% [markdown]
# ### What my app can do:
# - Help you explore the data and it's features
# - Good for deeper dive after descriptive stats
# - Help you get an intuition for participant variability
# - Help you get an intuition for the timeseries
# - Help you get an intuition for feature relationships in single cases
# - Did I mention it's interactive?
# - Where did the questionnaires work and where maybe not so much?
# - Have the scales been used as intended?
# - Helps exclude critical participants
